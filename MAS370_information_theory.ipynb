# %%
from matplotlib import pyplot as plt
import random
import math
import numpy as np

# %%
random.uniform(-2,2)
# Out:
# -1.3854210590055733

# %%
num_of_data = 40
data = [ (random.randint(1, 13), random.randint(1, 13)) for i in range(num_of_data) ]

# %%
# %matplotlib inline

# %%
x = [a[0] for a in data]
y = [a[1] for a in data]

# %%
plt.scatter(x,y)

# %%
K = 3
while len(centroids) != K:
    centroids = [ ( random.randint(min(x),max(x)), random.randint(min(y),max(y)) ) for i in range(K)]
x_cet = [ i[0] for i in centroids ]
y_cet = [ i[1] for i in centroids ]
plt.scatter(x, y, c="blue")
plt.scatter(x_cet, y_cet, c="red")

# %%
import math
def distance(x, y):
    return math.sqrt( (x[0]-y[0])**2 + (x[1]-y[1])**2 )

# %%
codewords = []
colors = ["red", "blue", "green"]
S = [[] for i in range(K)]
for _dat in data:
    _dist = [ distance(_dat, i) for i in centroids ]
    _index = _dist.index(min(_dist))
    codewords.append( colors[_index] )
    S[_index].append(_dat)

# %%
codewords
# Out:
# ['green',
#  'red',
#  'green',
#  'green',
#  'green',
#  'red',
#  'red',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'blue',
#  'green',
#  'green',
#  'green',
#  'red',
#  'green',
#  'red',
#  'red',
#  'green',
#  'red',
#  'red',
#  'green',
#  'blue',
#  'red',
#  'green',
#  'green',
#  'green',
#  'green',
#  'red',
#  'green',
#  'green',
#  'red',
#  'green',
#  'red',
#  'blue',
#  'green',
#  'green']

# %%
plt.scatter(x,y,c=codewords)
plt.scatter(x_cet, y_cet, c=colors)

# %%
S
# Out:
# [[(1, 2),
#   (6, 2),
#   (5, 3),
#   (3, 6),
#   (3, 5),
#   (2, 1),
#   (6, 3),
#   (8, 1),
#   (2, 6),
#   (5, 8),
#   (2, 2),
#   (4, 3)],
#  [(3, 13), (1, 10), (1, 13)],
#  [(11, 2),
#   (11, 6),
#   (10, 4),
#   (10, 5),
#   (11, 2),
#   (6, 11),
#   (13, 12),
#   (13, 12),
#   (6, 12),
#   (13, 10),
#   (13, 3),
#   (10, 3),
#   (6, 11),
#   (9, 10),
#   (9, 9),
#   (10, 3),
#   (7, 11),
#   (13, 2),
#   (7, 8),
#   (7, 5),
#   (8, 3),
#   (12, 9),
#   (6, 13),
#   (9, 6),
#   (10, 8)]]

# %%
new_centroids = []
for _cds in S:
    _x = 0
    _y = 0
    _len = len(_cds)
    for _c in _cds:
        _x += _c[0]
        _y += _c[1]
    new_centroids.append( (_x/_len,_y/_len) )

# %%
new_centroids
# Out:
# [(3.9166666666666665, 3.5), (1.6666666666666667, 12.0), (9.6, 7.2)]

# %%
x_newcet = [ i[0] for i in new_centroids ]
y_newcet = [ i[1] for i in new_centroids ]

# %%
plt.scatter(x,y,c=codewords)
plt.scatter(x_newcet, y_newcet, c="black")

# %%
num_of_data = 40
data = [ (random.randint(1, 13), random.randint(1, 13)) for i in range(num_of_data) ]

x = [a[0] for a in data]
y = [a[1] for a in data]

K = 3
while len(centroids) != K:
    centroids = [ ( random.randint(min(x),max(x)), random.randint(min(y),max(y)) ) for i in range(K)]
x_cet = [ i[0] for i in centroids ]
y_cet = [ i[1] for i in centroids ]
plt.scatter(x, y, c="blue")
plt.scatter(x_cet, y_cet, c="red")
plt.show()

# ------------------------------------------------------------------
def get_cluster(x, y, K, centroids):
    error = 0
    codewords = []
    colors = ["black", "blue", "green"]
    S = [[] for i in range(K)]
    for _dat in data:
        _dist = [ distance(_dat, i) for i in centroids ]
        error += min(_dist)
        _index = _dist.index(min(_dist))
        codewords.append( colors[_index] )
        S[_index].append(_dat)
    return codewords, error

codewords = get_cluster(x, y, K, centroids)
plt.scatter(x,y,c=codewords)
plt.scatter(x_cet, y_cet, c="black")
plt.show()

# ------------------------------------------------------------------
new_centroids = []
for _cds in S:
    _x = 0
    _y = 0
    _len = len(_cds)
    for _c in _cds:
        _x += _c[0]
        _y += _c[1]
    new_centroids.append( (_x/_len,_y/_len) )

x_newcet = [ i[0] for i in new_centroids ]
y_newcet = [ i[1] for i in new_centroids ]

plt.scatter(x,y,c=codewords)
plt.scatter(x_newcet, y_newcet, c="black")
plt.show()

#---------------------------------------------------------------------
codewords = get_cluster(x, y, K, new_centroids)
plt.scatter(x,y,c=codewords)
plt.scatter(x_newcet, y_newcet, c="black")
plt.show()

# %% [markdown]
# # LBG Algorithm Final

# %%
def get_cluster(x, y, K, centroids):
    error = 0
    codewords = []
    colors = ["black", "blue", "green", "yellow", "purple"]
    S = [[] for i in range(K)]
    for _dat in data:
        _dist = [ distance(_dat, i) for i in centroids ]
        error += min(_dist)
        _index = _dist.index(min(_dist))
        codewords.append( colors[_index] )
        S[_index].append(_dat)
    return codewords, S, error

# %%
num_of_data = 50
data = [ (random.randint(1, 13), random.randint(1, 13)) for i in range(num_of_data) ]

x = [a[0] for a in data]
y = [a[1] for a in data]

K = 5
while len(centroids) != K:
    centroids = [ ( random.randint(min(x),max(x)), random.randint(min(y),max(y)) ) for i in range(K)]
x_cet = [ i[0] for i in centroids ]
y_cet = [ i[1] for i in centroids ]
plt.scatter(x, y, c="blue")
plt.scatter(x_cet, y_cet, c="red")
plt.show()

error = []
distortion = 9999
k = 0
while True:
    codewords, S, err = get_cluster(x, y, K, centroids)
    error.append(err)
    print("================" * 3)
    print(" k : " + str(k))
    if k == 0:
        distortion = 9999
        print(" error : " + str( error[-1] ) )
    else:
        distortion = (error[-2] - err) / err
        print(" error : " + str(distortion) )
    print("================" * 3)
    plt.scatter(x,y,c=codewords)
    plt.scatter(x_cet, y_cet, c="red")
    plt.show()
    
    if distortion < 0.01:
        break
    else:
        #---------------------------------------------------------------------
        new_centroids = []
        for _cds in S:
            _x = 0
            _y = 0
            _len = len(_cds)
            for _c in _cds:
                _x += _c[0]
                _y += _c[1]
            new_centroids.append( (_x/_len,_y/_len) )

        x_cet = [ i[0] for i in new_centroids ]
        y_cet = [ i[1] for i in new_centroids ]
        
        centroids = new_centroids
        k += 1
# Out:
# ================================================
#  k : 0
#  error : 112.17053891130088
# ================================================
# ================================================
#  k : 1
#  error : 0.15945294514473216
# ================================================
# ================================================
#  k : 2
#  error : 0.04232759010427289
# ================================================
# ================================================
#  k : 3
#  error : 0.002798711912458236
# ================================================

# %% [markdown]
# # Image Compression

# %%
import cv2
img_1 = cv2.imread('original.jpeg')

data = []
for i in range(img_1.shape[0]):
    for j in range(img_1.shape[1]):
        data.append( img_1[i][j].tolist() )

# %%
def distance(x, y):
    _res = 0
    for i in range( len(x) ):
        _res += (x[i]-y[i])**2
    return math.sqrt( _res )

# %%
def get_cluster(K, centroids, data):
    error = 0
    S = [[] for i in range(K)]
    codeword = []
    for _dat in data:
        _dist = [ distance(_dat, i) for i in centroids ]
        error += min(_dist)
        _index = _dist.index(min(_dist))
        S[_index].append(_dat)
        codeword.append( centroids[_index] )
    return codeword, S, error

# %%
def lbg(data, K):
    num_of_data = len(data)
    dim = len(data[0])
    
    centroids = []
    while len(centroids) != K:
        for i in range(K):
            centroids.append( [ random.randint(0,255) for j in range(dim) ] )

    error = []
    distortion = 9999
    k = 0
    while True:
        codeword, S, err = get_cluster(K, centroids, data)
        error.append(err)

        if k == 0:
            distortion = error[-1]
        else:
            distortion = (error[-2] - err) / err


        if distortion < 0.1:
            break
        else:
            new_centroids = []
            for _cds in S:
                _tmp = [0] * dim
                _len = len(_cds)
                if _len != 0:
                    for _c in _cds:
                        for i in range(dim):
                            _tmp[i] += _c[i]
                    for i in range(dim):
                        _tmp[i] = _tmp[i] / _len
                
                    new_centroids.append( _tmp )
                else:
                    new_centroids.append( [ random.randint(0,255) for j in range(dim) ] )

            centroids = new_centroids
            k += 1
    return centroids, S, codeword

# %%
cent, S, codeword = lbg(data, 30)

# %%
target = img_1.copy()
for i in range( img_1.shape[0] ):
    for j in range( img_1.shape[1] ):
        _dat = target[i][j]
        dist = [ distance(_dat, i) for i in cent ]
        index = dist.index(min(dist))
        target[i][j] = cent[index]

# %%
plt.imshow(img_1)

# %%
# 100
plt.imshow(target)

# %%
# 10
plt.imshow(target)

# %%
# 20
plt.imshow(target)

# %%
# 2
plt.imshow(target)

# %%
from PIL import Image
im = Image.fromarray(target)
im.save("100.jpeg")

# %%
target_200 = target

# %%
# 200
plt.imshow(target)

# %%
# 15
plt.imshow(target)

# %%
# 3
plt.imshow(target)

# %%
S
# Out:
# [[[116, 118, 129],
#   [115, 117, 128],
#   [114, 119, 128],
#   [114, 122, 129],
#   [113, 123, 130],
#   [109, 124, 126],
#   [108, 123, 125],
#   [106, 124, 123],
#   [105, 123, 122],
#   [97, 115, 114],
#   [101, 118, 115],
#   [98, 115, 112],
#   [75, 87, 87],
#   [82, 86, 87],
#   [112, 116, 117],
#   [127, 131, 132],
#   [137, 139, 140],
#   [143, 143, 143],
#   [117, 119, 130],
#   [113, 118, 127],
#   [112, 117, 126],
#   [111, 119, 126],
#   [108, 120, 124],
#   [105, 120, 122],
#   [101, 119, 120],
#   [100, 118, 117],
#   [99, 117, 116],
#   [92, 110, 109],
#   [88, 105, 102],
#   [75, 89, 87],
#   [78, 82, 83],
#   [109, 113, 114],
#   [136, 138, 139],
#   [139, 139, 139],
#   [115, 120, 129],
#   [111, 118, 127],
#   [110, 117, 126],
#   [108, 118, 125],
#   [109, 121, 125],
#   [108, 123, 125],
#   [104, 122, 123],
#   [101, 119, 118],
#   [95, 114, 111],
#   [83, 102, 99],
#   [69, 86, 83],
#   [79, 83, 84],
#   [113, 117, 118],
#   [130, 132, 132],
#   [143, 145, 145],
#   [114, 121, 130],
#   [111, 120, 129],
#   [109, 119, 126],
#   [108, 120, 126],
#   [108, 123, 126],
#   [107, 125, 126],
#   [104, 122, 121],
#   [98, 116, 115],
#   [88, 107, 104],
#   [67, 86, 83],
#   [82, 86, 87],
#   [121, 123, 123],
#   [137, 139, 139],
#   [143, 145, 145],
#   [142, 144, 144],
#   [113, 122, 131],
#   [111, 122, 130],
#   [108, 120, 126],
#   [105, 119, 125],
#   [106, 121, 124],
#   [103, 121, 122],
#   [95, 113, 112],
#   [83, 104, 102],
#   [73, 92, 89],
#   [96, 101, 100],
#   [121, 126, 125],
#   [136, 141, 140],
#   [137, 142, 141],
#   [141, 146, 145],
#   [141, 146, 145],
#   [106, 119, 127],
#   [106, 120, 126],
#   [105, 119, 125],
#   [102, 119, 122],
#   [104, 122, 123],
#   [102, 120, 121],
#   [87, 108, 106],
#   [73, 94, 92],
#   [102, 108, 107],
#   [131, 136, 135],
#   [136, 141, 140],
#   [137, 142, 141],
#   [139, 144, 143],
#   [102, 118, 124],
#   [103, 119, 125],
#   [102, 118, 124],
#   [99, 118, 121],
#   [99, 119, 120],
#   [94, 114, 115],
#   [79, 97, 96],
#   [75, 83, 82],
#   [110, 116, 115],
#   [127, 133, 132],
#   [135, 141, 140],
#   [139, 145, 144],
#   [105, 124, 129],
#   [105, 124, 127],
#   [102, 121, 124],
#   [97, 117, 118],
#   [92, 112, 113],
#   [82, 103, 101],
#   [83, 91, 90],
#   [110, 118, 117],
#   [134, 140, 139],
#   [140, 146, 145],
#   [140, 146, 145],
#   [99, 118, 121],
#   [104, 123, 126],
#   [100, 119, 122],
#   [91, 111, 112],
#   [86, 104, 105],
#   [69, 87, 86],
#   [96, 104, 104],
#   [126, 134, 134],
#   [139, 147, 147],
#   [140, 145, 146],
#   [138, 143, 144],
#   [95, 114, 117],
#   [100, 120, 121],
#   [97, 117, 118],
#   [89, 110, 108],
#   [78, 96, 95],
#   [106, 114, 114],
#   [127, 135, 135],
#   [137, 142, 143],
#   [140, 144, 145],
#   [143, 145, 146],
#   [100, 118, 119],
#   [99, 117, 118],
#   [96, 114, 115],
#   [85, 103, 102],
#   [89, 94, 95],
#   [117, 122, 123],
#   [133, 138, 139],
#   [105, 120, 122],
#   [97, 112, 114],
#   [88, 104, 103],
#   [73, 89, 88],
#   [106, 111, 112],
#   [126, 131, 132],
#   [140, 145, 146],
#   [104, 118, 117],
#   [89, 103, 102],
#   [77, 91, 90],
#   [90, 95, 96],
#   [117, 122, 123],
#   [134, 139, 140],
#   [140, 144, 145],
#   [142, 146, 147],
#   [99, 113, 112],
#   [83, 97, 96],
#   [71, 83, 83],
#   [106, 111, 112],
#   [132, 137, 138],
#   [140, 144, 145],
#   [99, 111, 111],
#   [81, 93, 93],
#   [88, 91, 95],
#   [124, 127, 131],
#   [138, 143, 146],
#   [141, 146, 149],
#   [97, 111, 110],
#   [78, 90, 90],
#   [110, 113, 117],
#   [132, 135, 139],
#   [137, 142, 145],
#   [90, 105, 107],
#   [73, 89, 88],
#   [96, 96, 102],
#   [124, 124, 130],
#   [136, 139, 144],
#   [94, 109, 111],
#   [78, 93, 95],
#   [82, 82, 88],
#   [121, 121, 127],
#   [135, 135, 141],
#   [141, 142, 146],
#   [141, 142, 146],
#   [145, 144, 146],
#   [96, 108, 112],
#   [81, 94, 96],
#   [71, 83, 85],
#   [99, 102, 107],
#   [122, 125, 130],
#   [141, 142, 146],
#   [93, 104, 108],
#   [81, 92, 96],
#   [77, 86, 89],
#   [86, 89, 94],
#   [116, 119, 124],
#   [142, 143, 147],
#   [94, 103, 107],
#   [84, 93, 97],
#   [82, 91, 95],
#   [69, 84, 87],
#   [70, 85, 88],
#   [69, 90, 92],
#   [65, 88, 90],
#   [65, 86, 88],
#   [64, 85, 87],
#   [64, 85, 87],
#   [89, 92, 97],
#   [117, 120, 125],
#   [136, 139, 144],
#   [137, 140, 144],
#   [137, 140, 144],
#   [138, 142, 143],
#   [140, 144, 145],
#   [141, 144, 148],
#   [142, 145, 149],
#   [94, 100, 105],
#   [84, 90, 95],
#   [84, 90, 95],
#   [68, 83, 86],
#   [71, 88, 91],
#   [68, 87, 90],
#   [62, 85, 87],
#   [62, 85, 87],
#   [64, 85, 87],
#   [66, 85, 88],
#   [68, 87, 90],
#   [70, 87, 90],
#   [68, 85, 88],
#   [69, 84, 87],
#   [72, 87, 89],
#   [68, 83, 85],
#   [69, 85, 84],
#   [69, 85, 84],
#   [69, 85, 84],
#   [70, 86, 85],
#   [80, 83, 88],
#   [111, 114, 119],
#   [134, 137, 142],
#   [137, 140, 145],
#   [138, 141, 145],
#   [139, 142, 146],
#   [140, 144, 145],
#   [141, 144, 148],
#   [142, 145, 149],
#   [141, 147, 146],
#   [134, 140, 139],
#   [136, 142, 141],
#   [93, 96, 104],
#   [81, 84, 92],
#   [82, 86, 91],
#   [68, 85, 88],
#   [71, 90, 93],
#   [69, 89, 94],
#   [63, 85, 90],
#   [61, 86, 88],
#   [64, 87, 89],
#   [66, 87, 89],
#   [66, 87, 89],
#   [68, 87, 90],
#   [68, 87, 90],
#   [69, 86, 89],
#   [68, 85, 88],
#   [69, 84, 87],
#   [67, 82, 85],
#   [104, 107, 112],
#   [133, 136, 140],
#   [141, 144, 148],
#   [141, 146, 149],
#   [140, 145, 148],
#   [142, 146, 147],
#   [140, 143, 148],
#   [140, 143, 148],
#   [129, 135, 134],
#   [125, 131, 130],
#   [132, 138, 137],
#   [93, 96, 104],
#   [81, 84, 92],
#   [82, 86, 91],
#   [65, 86, 88],
#   [64, 84, 89],
#   [65, 90, 92],
#   [64, 89, 91],
#   [63, 88, 90],
#   [64, 89, 91],
#   [66, 89, 91],
#   [67, 90, 92],
#   [68, 89, 91],
#   [68, 87, 90],
#   [74, 84, 84],
#   [75, 85, 85],
#   [74, 86, 86],
#   [77, 89, 89],
#   [76, 90, 89],
#   [76, 90, 89],
#   [74, 89, 91],
#   [75, 90, 92],
#   [69, 87, 88],
#   [68, 86, 87],
#   [65, 85, 86],
#   [65, 87, 85],
#   [64, 86, 84],
#   [68, 86, 87],
#   [69, 87, 88],
#   [68, 83, 85],
#   [68, 83, 85],
#   [69, 84, 86],
#   [70, 85, 87],
#   [73, 86, 88],
#   [73, 86, 88],
#   [74, 86, 90],
#   [74, 86, 90],
#   [72, 83, 87],
#   [106, 109, 113],
#   [131, 134, 138],
#   [136, 139, 143],
#   [138, 143, 146],
#   [141, 146, 149],
#   [140, 145, 148],
#   [139, 144, 145],
#   [140, 144, 145],
#   [140, 142, 150],
#   [140, 143, 148],
#   [139, 145, 144],
#   [130, 137, 134],
#   [121, 127, 126],
#   [122, 128, 127],
#   [135, 141, 140],
#   [90, 94, 99],
#   [80, 84, 89],
#   [80, 84, 89],
#   [83, 87, 92],
#   [64, 85, 87],
#   [64, 85, 87],
#   [63, 86, 88],
#   [63, 86, 88],
#   [68, 89, 91],
#   [70, 91, 93],
#   [69, 88, 91],
#   [71, 85, 84],
#   [71, 86, 88],
#   [70, 85, 87],
#   [70, 88, 89],
#   [69, 87, 88],
#   [68, 88, 89],
#   [69, 89, 90],
#   [64, 85, 87],
#   [64, 85, 87],
#   [68, 91, 93],
#   [65, 91, 91],
#   [62, 88, 88],
#   [63, 89, 89],
#   [67, 93, 93],
#   [67, 92, 94],
#   [62, 87, 89],
#   [63, 86, 88],
#   [66, 89, 91],
#   [65, 86, 88],
#   [66, 87, 89],
#   [65, 85, 90],
#   [68, 88, 93],
#   [74, 93, 98],
#   [71, 90, 95],
#   [69, 88, 93],
#   [78, 94, 100],
#   [81, 93, 99],
#   [96, 99, 103],
#   [123, 126, 130],
#   [135, 139, 140],
#   [140, 145, 146],
#   [140, 145, 146],
#   [137, 142, 143],
#   [138, 143, 144],
#   [142, 146, 147],
#   [142, 146, 147],
#   [133, 138, 137],
#   [119, 124, 122],
#   [123, 128, 127],
#   [137, 142, 141],
#   [88, 92, 97],
#   [80, 84, 89],
#   [82, 86, 91],
#   [85, 90, 93],
#   [79, 84, 87],
#   [65, 84, 87],
#   [71, 84, 86],
#   [71, 86, 88],
#   [70, 85, 87],
#   [68, 86, 87],
#   [72, 90, 91],
#   [74, 94, 95],
#   [74, 93, 96],
#   [69, 90, 92],
#   [66, 87, 89],
#   [65, 88, 90],
#   [65, 90, 92],
#   [62, 90, 91],
#   [63, 91, 92],
#   [65, 93, 94],
#   [66, 93, 97],
#   [64, 91, 95],
#   [66, 91, 95],
#   [67, 92, 96],
#   [63, 88, 92],
#   [65, 90, 94],
#   [66, 88, 94],
#   [70, 92, 98],
#   [76, 98, 104],
#   [73, 95, 101],
#   [71, 93, 99],
#   [78, 97, 104],
#   [86, 100, 106],
#   [78, 90, 96],
#   [78, 89, 93],
#   [96, 100, 101],
#   [121, 125, 126],
#   [133, 137, 138],
#   [139, 143, 144],
#   [139, 144, 145],
#   [138, 143, 144],
#   [141, 146, 147],
#   [142, 145, 150],
#   [142, 146, 147],
#   [127, 132, 131],
#   [120, 125, 124],
#   [113, 118, 116],
#   [122, 127, 126],
#   [139, 144, 143],
#   [82, 89, 92],
#   [77, 84, 87],
#   [78, 85, 88],
#   [78, 85, 88],
#   [73, 80, 83],
#   [68, 86, 87],
#   [73, 90, 93],
#   [71, 90, 93],
#   [68, 87, 90],
#   [66, 87, 89],
#   [65, 90, 94],
#   [65, 92, 96],
#   [66, 93, 97],
#   [65, 92, 96],
#   [65, 91, 97],
#   [66, 92, 98],
#   [65, 91, 97],
#   [63, 89, 95],
#   [68, 94, 100],
#   [69, 95, 101],
#   [68, 91, 99],
#   [69, 92, 100],
#   [74, 97, 105],
#   [72, 95, 103],
#   [68, 91, 99],
#   [73, 95, 101],
#   [83, 99, 105],
#   [81, 95, 101],
#   [83, 95, 99],
#   [94, 96, 96],
#   [120, 122, 122],
#   [131, 136, 135],
#   [138, 143, 142],
#   [138, 143, 142],
#   [137, 142, 143],
#   [141, 146, 147],
#   [139, 143, 144],
#   [128, 132, 133],
#   [112, 117, 116],
#   [104, 109, 108],
#   [108, 113, 111],
#   [124, 129, 128],
#   [142, 147, 146],
#   [90, 97, 100],
#   [87, 94, 97],
#   [87, 94, 97],
#   [81, 91, 91],
#   [75, 85, 85],
#   [74, 85, 83],
#   [67, 84, 87],
#   [67, 88, 90],
#   [68, 93, 95],
#   [69, 94, 98],
#   [66, 91, 95],
#   [66, 91, 95],
#   [69, 94, 98],
#   [67, 92, 96],
#   [61, 86, 90],
#   [71, 95, 101],
#   [72, 96, 102],
#   [67, 91, 97],
#   [66, 90, 96],
#   [71, 95, 101],
#   [69, 95, 101],
#   [67, 91, 97],
#   [72, 94, 100],
#   [83, 99, 105],
#   [85, 99, 105],
#   [88, 100, 104],
#   [93, 96, 94],
#   [119, 121, 121],
#   [133, 135, 135],
#   [140, 142, 142],
#   [137, 142, 141],
#   [135, 139, 140],
#   [138, 144, 143],
#   [141, 146, 145],
#   [136, 140, 141],
#   [127, 131, 132],
#   [113, 117, 118],
#   [100, 105, 104],
#   [94, 99, 98],
#   [109, 114, 112],
#   [131, 136, 135],
#   [92, 102, 102],
#   [88, 98, 98],
#   [87, 97, 97],
#   [79, 91, 91],
#   [66, 85, 88],
#   [67, 86, 89],
#   [70, 89, 92],
#   [75, 94, 97],
#   [74, 95, 97],
#   [69, 90, 92],
#   [70, 92, 97],
#   [71, 93, 98],
#   [67, 89, 94],
#   [66, 88, 93],
#   [72, 94, 99],
#   [73, 98, 102],
#   [74, 96, 101],
#   [80, 100, 105],
#   [90, 106, 112],
#   [95, 109, 115],
#   [99, 111, 115],
#   [84, 96, 98],
#   [86, 87, 85],
#   [106, 107, 103],
#   [124, 125, 123],
#   [131, 134, 132],
#   [136, 139, 137],
#   [133, 138, 136],
#   [133, 138, 137],
#   [138, 143, 142],
#   [141, 146, 144],
#   [139, 144, 142],
#   [139, 144, 142],
#   [142, 147, 145],
#   [142, 147, 145],
#   [139, 144, 143],
#   [134, 139, 138],
#   [128, 132, 133],
#   [114, 118, 119],
#   [96, 100, 101],
#   [86, 91, 90],
#   [93, 98, 97],
#   [116, 121, 119],
#   [141, 146, 145],
#   [91, 101, 101],
#   [81, 93, 93],
#   [75, 87, 87],
#   [72, 88, 87],
#   [74, 92, 93],
#   [74, 92, 93],
#   [72, 92, 93],
#   [76, 96, 97],
#   [74, 94, 95],
#   [70, 91, 92],
#   [74, 95, 96],
#   [76, 97, 99],
#   [75, 96, 98],
#   [78, 99, 101],
#   [92, 108, 114],
#   [100, 115, 118],
#   [106, 118, 120],
#   [103, 112, 115],
#   [99, 107, 107],
#   [100, 105, 104],
#   [105, 108, 106],
#   [109, 110, 106],
#   [118, 117, 113],
#   [127, 126, 122],
#   [130, 131, 127],
#   [132, 133, 129],
#   [133, 136, 134],
#   [134, 137, 135],
#   [133, 138, 137],
#   [141, 146, 144],
#   [139, 144, 142],
#   [136, 141, 139],
#   [136, 141, 139],
#   [140, 145, 143],
#   [141, 146, 144],
#   [139, 144, 142],
#   [140, 145, 144],
#   [142, 146, 147],
#   [141, 145, 146],
#   [142, 146, 147],
#   [136, 141, 140],
#   [139, 144, 143],
#   [136, 141, 140],
#   [130, 135, 134],
#   [121, 125, 126],
#   [101, 105, 106],
#   [81, 85, 86],
#   [76, 81, 80],
#   [95, 100, 99],
#   [125, 130, 128],
#   [78, 91, 89],
#   [75, 91, 90],
#   [74, 92, 91],
#   [72, 90, 89],
#   [76, 94, 93],
#   [74, 94, 95],
#   [73, 93, 94],
#   [75, 95, 96],
#   [88, 105, 108],
#   [99, 114, 117],
#   [106, 118, 120],
#   [108, 117, 120],
#   [108, 116, 116],
#   [112, 117, 116],
#   [122, 125, 123],
#   [126, 127, 123],
#   [135, 134, 130],
#   [138, 138, 132],
#   [137, 137, 131],
#   [134, 136, 130],
#   [136, 140, 135],
#   [137, 141, 136],
#   [136, 141, 139],
#   [142, 147, 145],
#   [142, 147, 145],
#   [138, 144, 139],
#   [138, 143, 141],
#   [142, 147, 145],
#   [141, 146, 144],
#   [142, 147, 145],
#   [141, 145, 146],
#   [141, 145, 146],
#   [140, 145, 144],
#   [121, 126, 125],
#   [127, 132, 131],
#   [123, 128, 127],
#   [113, 118, 117],
#   [103, 107, 108],
#   [84, 88, 89],
#   [97, 102, 101],
#   [129, 134, 132],
#   [70, 84, 82],
#   [71, 88, 85],
#   [76, 92, 91],
#   [77, 95, 94],
#   [77, 95, 94],
#   [80, 98, 97],
#   [87, 105, 106],
#   [100, 115, 117],
#   [106, 119, 121],
#   [108, 120, 120],
#   [110, 118, 117],
#   [112, 119, 116],
#   [125, 129, 124],
#   [131, 133, 127],
#   [137, 137, 131],
#   [139, 139, 133],
#   [138, 138, 132],
#   [138, 139, 135],
#   [143, 147, 142],
#   [140, 145, 143],
#   [137, 142, 140],
#   [141, 146, 144],
#   [141, 146, 144],
#   [141, 146, 144],
#   [142, 146, 147],
#   [142, 146, 147],
#   [137, 143, 142],
#   [123, 128, 129],
#   [105, 110, 111],
#   [111, 116, 117],
#   [103, 108, 109],
#   [90, 95, 96],
#   [80, 85, 86],
#   [75, 80, 81],
#   [95, 101, 100],
#   [129, 136, 133],
#   [85, 90, 93],
#   [86, 90, 95],
#   [95, 99, 104],
#   [92, 98, 105],
#   [82, 88, 93],
#   [75, 84, 88],
#   [71, 80, 84],
#   [75, 92, 89],
#   [83, 102, 99],
#   [89, 107, 108],
#   [97, 115, 116],
#   [109, 123, 122],
#   [112, 125, 123],
#   [115, 124, 121],
#   [119, 126, 121],
#   [128, 132, 126],
#   [134, 139, 130],
#   [139, 142, 133],
#   [138, 140, 134],
#   [139, 141, 135],
#   [141, 142, 138],
#   [140, 143, 141],
#   [138, 143, 142],
#   [139, 143, 144],
#   [140, 145, 146],
#   [142, 147, 146],
#   [142, 147, 146],
#   [142, 147, 146],
#   [142, 146, 147],
#   [129, 139, 139],
#   [98, 107, 110],
#   [76, 88, 90],
#   [78, 90, 92],
#   [76, 88, 90],
#   [97, 108, 106],
#   [122, 133, 131],
#   [80, 85, 88],
#   [87, 91, 96],
#   [99, 105, 112],
#   [105, 111, 118],
#   [100, 108, 115],
#   [99, 109, 116],
#   [95, 107, 113],
#   [88, 100, 106],
#   [83, 97, 103],
#   [75, 89, 95],
#   [75, 89, 95],
#   [72, 84, 90],
#   [74, 91, 88],
#   [85, 103, 102],
#   [97, 115, 114],
#   [111, 125, 124],
#   [114, 128, 124],
#   [118, 127, 124],
#   [122, 129, 124],
#   [126, 133, 126],
#   [130, 135, 126],
#   [136, 139, 130],
#   [138, 140, 134],
#   [142, 143, 139],
#   [142, 146, 141],
#   [141, 146, 145],
#   [140, 146, 145],
#   [142, 147, 146],
#   [141, 146, 145],
#   [141, 146, 145],
#   [142, 146, 147],
#   [131, 141, 141],
#   [124, 136, 136],
#   [112, 124, 126],
#   [78, 91, 93],
#   [69, 81, 85],
#   [72, 84, 84],
#   [84, 96, 96],
#   [105, 118, 116],
#   [126, 139, 137],
#   [135, 148, 146],
#   [75, 80, 83],
#   [87, 93, 98],
#   [101, 109, 116],
#   [110, 118, 125],
#   [110, 120, 127],
#   [112, 124, 130],
#   [109, 123, 129],
#   [105, 119, 125],
#   [103, 119, 125],
#   [97, 113, 120],
#   [99, 115, 122],
#   [98, 111, 119],
#   [88, 101, 109],
#   [83, 94, 102],
#   [74, 85, 93],
#   [68, 84, 83],
#   [86, 102, 101],
#   [105, 119, 118],
#   [112, 126, 122],
#   [119, 128, 125],
#   [127, 134, 129],
#   [130, 137, 130],
#   [129, 133, 127],
#   [135, 137, 131],
#   [139, 141, 135],
#   [141, 145, 140],
#   [142, 146, 141],
#   [138, 143, 142],
#   [135, 141, 140],
#   [136, 141, 144],
#   [138, 143, 144],
#   [141, 146, 145],
#   [142, 147, 146],
#   [139, 147, 147],
#   [123, 132, 135],
#   [106, 118, 120],
#   [92, 103, 107],
#   [71, 83, 87],
#   [76, 88, 92],
#   [86, 98, 102],
#   [100, 112, 114],
#   [98, 110, 110],
#   [108, 120, 120],
#   [121, 133, 133],
#   [133, 145, 145],
#   [77, 85, 85],
#   [89, 98, 102],
#   [100, 110, 117],
#   [106, 116, 123],
#   [105, 117, 123],
#   [107, 121, 127],
#   [105, 121, 127],
#   [104, 120, 126],
#   [104, 123, 128],
#   [107, 125, 132],
#   [105, 123, 130],
#   [99, 117, 124],
#   [94, 112, 119],
#   [101, 116, 125],
#   [102, 117, 126],
#   [88, 100, 110],
#   [67, 79, 89],
#   [83, 95, 95],
#   [96, 107, 105],
#   [112, 119, 116],
#   [127, 133, 128],
#   [136, 140, 134],
#   [135, 139, 133],
#   [142, 144, 138],
#   [143, 147, 141],
#   [140, 146, 145],
#   [137, 145, 144],
#   [136, 143, 146],
#   [135, 143, 143],
#   [140, 145, 146],
#   [140, 145, 144],
#   [140, 145, 144],
#   [142, 147, 146],
#   [133, 143, 143],
#   [117, 129, 131],
#   [86, 98, 102],
#   [70, 82, 86],
#   [73, 87, 93],
#   [99, 113, 119],
#   [115, 129, 135],
#   [117, 132, 135],
#   [119, 131, 137],
#   [121, 133, 137],
#   [122, 134, 136],
#   [122, 134, 134],
#   [126, 138, 138],
#   [134, 146, 146],
#   [81, 80, 82],
#   [86, 94, 94],
#   [90, 101, 105],
#   [99, 111, 115],
#   [102, 114, 118],
#   [104, 116, 120],
#   [107, 121, 127],
#   [105, 121, 127],
#   [102, 120, 127],
#   [104, 123, 130],
#   [111, 130, 138],
#   [109, 128, 136],
#   [101, 120, 128],
#   [95, 114, 122],
#   [97, 115, 126],
#   [101, 119, 130],
#   [96, 112, 124],
#   [84, 100, 112],
#   [72, 89, 98],
#   [66, 82, 89],
#   [84, 91, 88],
#   [109, 115, 110],
#   [129, 133, 127],
#   [136, 140, 134],
#   [135, 139, 133],
#   [138, 142, 136],
#   [141, 145, 140],
#   [139, 144, 142],
#   [140, 146, 145],
#   [139, 146, 149],
#   [135, 143, 143],
#   [138, 143, 144],
#   [139, 144, 143],
#   [141, 146, 145],
#   [138, 146, 146],
#   [115, 125, 125],
#   [91, 103, 105],
#   [83, 99, 106],
#   [108, 124, 131],
#   [124, 140, 147],
#   [132, 148, 155],
#   [132, 145, 153],
#   [125, 139, 145],
#   [127, 140, 142],
#   [127, 139, 141],
#   [129, 141, 143],
#   [135, 147, 149],
#   [88, 85, 87],
#   [93, 91, 91],
#   [85, 85, 85],
#   [77, 79, 79],
#   [77, 82, 81],
#   [89, 97, 96],
#   [89, 101, 103],
#   [95, 107, 111],
#   [100, 111, 115],
#   [105, 117, 121],
#   [111, 125, 131],
#   [111, 127, 133],
#   [106, 124, 131],
#   [108, 127, 134],
#   [109, 128, 136],
#   [109, 130, 138],
#   [106, 126, 137],
#   [96, 116, 127],
#   [87, 107, 118],
#   [86, 105, 118],
#   [94, 111, 124],
#   [98, 115, 128],
#   [95, 113, 124],
#   [87, 104, 113],
#   [75, 90, 99],
#   [100, 104, 99],
#   [115, 119, 113],
#   [126, 130, 124],
#   [133, 137, 132],
#   [137, 142, 140],
#   [139, 146, 143],
#   [140, 148, 147],
#   [139, 149, 149],
#   [135, 143, 143],
#   [132, 142, 142],
#   [111, 121, 121],
#   [82, 94, 96],
#   [75, 91, 98],
#   [100, 116, 123],
#   [114, 129, 138],
#   [122, 137, 146],
#   [120, 135, 144],
#   [121, 136, 145],
#   [129, 145, 152],
#   [132, 148, 155],
#   [130, 144, 150],
#   [130, 142, 146],
#   [133, 145, 147],
#   [137, 149, 151],
#   [90, 85, 87],
#   [90, 88, 88],

#   [162, 166, 167],
#   [162, 166, 167],
#   [162, 166, 167],
#   [162, 166, 167],
#   [161, 165, 166],
#   [165, 169, 170],
#   [164, 168, 169],
#   [164, 168, 169],
#   [163, 167, 168],
#   [163, 167, 168],
#   [162, 166, 167],
#   [162, 166, 167],
#   [162, 166, 167],
#   [161, 165, 166],
#   [160, 164, 165],
#   [160, 164, 165],
#   [162, 166, 167],
#   [162, 166, 167],
#   [160, 164, 165],
#   [160, 164, 165],
#   [161, 165, 166],
#   [162, 166, 167],
#   [161, 165, 166],
#   [159, 163, 164],
#   [159, 163, 164],
#   [161, 165, 166],
#   [163, 167, 168],
#   [164, 168, 169],
#   [164, 168, 169],
#   [163, 167, 168],
#   [163, 167, 168],
#   [163, 167, 168],
#   [163, 167, 168],
#   [163, 167, 168],
#   [162, 166, 167],
#   [161, 165, 166],
#   [161, 165, 166],
#   [162, 166, 167],
#   [162, 166, 167],
#   [162, 166, 167],
#   [162, 166, 167],
#   [163, 167, 168],
#   [163, 167, 168],
#   [164, 168, 169],
#   [164, 168, 169],
#   [162, 167, 166],
#   [162, 167, 166],
#   [161, 166, 165],
#   [160, 165, 164],
#   [162, 167, 166],
#   [165, 170, 169],
#   [164, 169, 168],
#   [160, 165, 164],
#   [161, 166, 165],
#   [161, 166, 165],
#   [162, 167, 166],
#   [163, 168, 167],
#   [164, 169, 168],
#   [164, 169, 168],
#   [165, 170, 169],
#   [165, 170, 169],
#   [161, 167, 166],
#   [161, 167, 166],
#   [161, 167, 166],
#   [162, 168, 167],
#   [164, 170, 169],
#   [163, 169, 168],
#   [162, 168, 167],
#   [161, 167, 166],
#   [161, 166, 165],
#   [162, 167, 166],
#   [163, 168, 167],
#   [162, 167, 166],
#   [161, 166, 165],
#   [162, 167, 166],
#   [163, 168, 167],
#   [164, 169, 168],
#   [162, 167, 166],
#   [162, 167, 166],
#   [163, 168, 167],
#   [163, 168, 167],
#   [164, 169, 168],
#   [165, 170, 169],
#   [166, 171, 170],
#   [167, 172, 171],
#   [166, 171, 170],
#   [166, 171, 170],
#   [149, 151, 151],
#   [154, 156, 156],
#   [148, 153, 152],
#   [143, 148, 147],
#   [145, 151, 150],
#   [146, 152, 151],
#   [143, 151, 150],
#   [142, 150, 149],
#   [144, 152, 151],
#   [147, 155, 154],
#   [148, 156, 155],
#   [148, 154, 153],
#   [147, 151, 152],
#   [148, 152, 153],
#   [148, 152, 153],
#   [149, 153, 154],
#   [150, 154, 155],
#   [150, 154, 155],
#   [151, 155, 156],
#   [151, 155, 156],
#   [147, 151, 152],
#   [148, 152, 153],
#   [149, 153, 154],
#   [150, 154, 155],
#   [151, 155, 156],
#   [151, 155, 156],
#   [151, 155, 156],
#   [150, 154, 155],
#   [148, 152, 153],
#   [149, 153, 154],
#   [151, 155, 156],
#   [153, 157, 158],
#   [154, 158, 159],
#   [154, 158, 159],
#   [153, 157, 158],
#   [153, 157, 158],
#   [152, 156, 157],
#   [152, 156, 157],
#   [151, 155, 156],
#   [152, 156, 157],
#   [154, 158, 159],
#   [154, 158, 159],
#   [153, 157, 158],
#   [152, 156, 157],
#   [153, 157, 158],
#   [153, 157, 158],
#   [154, 158, 159],
#   [154, 158, 159],
#   [154, 158, 159],
#   [155, 159, 160],
#   [155, 159, 160],
#   [155, 159, 160],
#   [151, 155, 156],
#   [151, 155, 156],
#   [151, 155, 156],
#   [152, 156, 157],
#   [154, 158, 159],

#   [13, 17, 18],
#   [13, 17, 18],
#   [13, 17, 18],
#   [13, 17, 18],
#   [13, 17, 18],
#   [13, 17, 18],
#   [15, 19, 20],
#   [15, 19, 20],
#   [14, 18, 19],
#   [15, 19, 20],
#   [16, 20, 21],
#   [16, 20, 21],
#   [13, 17, 18],
#   [11, 15, 16],
#   [14, 19, 20],
#   [11, 16, 17],
#   [11, 16, 17],
#   [16, 21, 22],
#   [20, 24, 25],
#   [20, 24, 25],
#   [18, 22, 23],
#   [17, 21, 22],
#   [17, 19, 20],
#   [18, 20, 21],
#   [19, 18, 20],
#   [17, 16, 18],
#   [16, 15, 17],
#   [18, 17, 19],
#   [20, 17, 19],
#   [18, 15, 17],
#   [18, 17, 19],
#   [18, 17, 19],
#   [18, 17, 19],
#   [18, 17, 19],
#   [18, 17, 19],
#   [18, 17, 19],
#   [18, 17, 19],
#   [18, 17, 19],
#   [17, 16, 18],
#   [18, 17, 19],
#   [19, 18, 20],
#   [20, 19, 21],
#   [20, 19, 21],
#   [20, 19, 21],
#   [20, 19, 21],
#   [19, 18, 20],
#   [17, 19, 20],
#   [17, 19, 20],
#   [17, 19, 20],
#   [18, 20, 21],
#   [18, 20, 21],
#   [17, 19, 20],
#   [17, 19, 20],
#   [17, 19, 20],
#   [19, 21, 22],
#   [22, 24, 25],
#   [22, 24, 25],
#   [18, 20, 21],
#   [16, 18, 19],
#   [19, 21, 22],
#   [22, 24, 25],
#   [19, 23, 24],
#   [16, 24, 24],
#   [36, 46, 46],
#   [65, 73, 73],
#   [55, 71, 70],
#   [26, 43, 40],
#   [10, 24, 22],
#   [9, 22, 20],
#   [12, 23, 21],
#   [12, 20, 19],
#   [10, 16, 15],
#   [11, 15, 16],
#   [14, 18, 19],
#   [17, 18, 22],
#   [16, 17, 21],
#   [19, 18, 20],
#   [23, 20, 22],
#   [23, 20, 22],
#   [21, 18, 20],
#   [19, 18, 20],
#   [21, 20, 22],
#   [19, 21, 22],
#   [17, 19, 20],
#   [16, 20, 21],
#   [15, 19, 20],
#   [14, 18, 19],
#   [14, 18, 19],
#   [13, 18, 19],
#   [13, 18, 19],
#   [14, 19, 20],
#   [15, 20, 21],
#   [13, 17, 18],
#   [13, 17, 18],
#   [13, 17, 18],
#   [15, 19, 20],
#   [17, 21, 22],
#   [17, 21, 22],
#   [15, 19, 20],
#   [13, 17, 18],
#   [13, 17, 18],
#   [11, 15, 16],
#   [11, 15, 16],
#   [14, 18, 19],
#   [14, 18, 19],
#   [13, 17, 18],
#   [15, 19, 20],
#   [18, 22, 23],
#   [13, 17, 18],
#   [14, 18, 19],
#   [14, 18, 19],
#   [15, 19, 20],
#   [15, 19, 20],
#   [15, 19, 20],
#   [15, 19, 20],
#   [14, 18, 19],
#   [13, 17, 18],
#   [13, 17, 18],
#   [13, 17, 18],
#   [15, 19, 20],
#   [17, 21, 22],
#   [18, 22, 23],
#   [16, 20, 21],
#   [15, 19, 20],
#   [13, 18, 19],
#   [11, 16, 17],
#   [12, 17, 18],
#   [16, 21, 22],
#   [20, 24, 25],
#   [19, 23, 24],
#   [17, 21, 22],
#   [17, 21, 22],
#   [15, 17, 18],
#   [16, 18, 19],
#   [18, 17, 19],
#   [17, 16, 18],
#   [17, 16, 18],
#   [20, 19, 21],
#   [20, 19, 21],
#   [19, 18, 20],
#   [19, 18, 20],
#   [19, 18, 20],
#   ...]]

# %%
data = []
for i in range(img_1.shape[0]):
    for j in range(img_1.shape[1]):
        data.append( img_1[i][j].tolist() )

# %%
len( cent )
# Out:
# 3

# %%
cent
# Out:
# [[108.73316002576608, 116.79913959694488, 123.33930707647005],
#  [174.54465285415614, 175.82557989754565, 174.711334383639],
#  [36.692084133786516, 41.042855031771836, 42.146199694596326]]

# %%
from PIL import Image
img = Image.open('cat.jpg').convert('LA')
img.save('greyscale.png')

# %%
import cv2
img = cv2.imread('greyscale.png',0)
img_1 = cv2.imread('cat.jpg')

# %%
type( img_1 )
# Out:
# numpy.ndarray

# %%
img_1.shape[-1]
# Out:
# 3

# %%
a = []

# %%
a.append( img_1[0][0].tolist() )
print(a)
# Out:
# [[116, 118, 129]]

# %%
img_1#.reshape([1,,img_1.shape[0]*img_1.shape[1]])
# Out:
# array([[[116, 118, 129],
#         [115, 117, 128],
#         [114, 119, 128],
#         ...,
#         [164, 169, 168],
#         [164, 169, 168],
#         [164, 169, 168]],
#
#        [[117, 119, 130],
#         [113, 118, 127],
#         [112, 117, 126],
#         ...,
#         [166, 171, 170],
#         [165, 170, 169],
#         [165, 170, 169]],
#
#        [[115, 120, 129],
#         [111, 118, 127],
#         [110, 117, 126],
#         ...,
#         [167, 172, 171],
#         [166, 171, 170],
#         [166, 171, 170]],
#
#        ...,
#        [[ 96, 117, 115],
#         [ 98, 119, 116],
#         [ 91, 112, 110],
#         ...,
#         [195, 192, 188],
#         [194, 191, 187],
#         [194, 191, 187]],
#
#        [[ 93, 116, 112],
#         [ 91, 114, 109],
#         [ 88, 111, 107],
#         ...,
#         [197, 192, 189],
#         [196, 191, 188],
#         [196, 191, 188]],
#
#        [[ 91, 117, 111],
#         [ 89, 115, 109],
#         [ 88, 111, 106],
#         ...,
#         [197, 192, 189],
#         [196, 191, 188],
#         [196, 191, 188]]], dtype=uint8)

# %%
img_1.shape
# Out:
# (418, 394, 3)

# %%
max( img.reshape(img_shape[0] * img_shape[1],) )
# Out:
# 253

# %%
cent, S = lbg(img, 3)
# Out:
# ================================================
#  error : 184.5597542190135
# ================================================
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-185-07079af6c958> in <module>
# ----> 1 cent, S = lbg(img, 3)
#
# <ipython-input-184-1ce07bcdd6c0> in lbg(data, K)
#      36                 for _c in _cds:
#      37                     for i in range(dim):
# ---> 38                         _tmp[i] += _c[i]
#      39                 new_centroids.append( _tmp/_len )
#      40
#
# IndexError: tuple index out of range

# %%
img = cv2.imread('greyscale.png',0)
flat_img = img.copy()
flat_img = flat_img.reshape(img.shape[0]*img.shape[1],)
flat_img.sort()
sorted_img = list(set( flat_img ))

# %%
K = 10
codeword = [ sorted_img[int( i * len(sorted_img) / K )] for i in range(1, K)]

# %%
codeword
# Out:
# [24, 49, 73, 98, 123, 147, 172, 196, 221]

# %%
target = img.copy()

# %%
for i in range( img.shape[0] ):
    for j in range( img.shape[1] ):
        _t = target[i][j]
        for k in range(K):
            if k == 0:
                if 0 <= _t < codeword[k]:
                    target[i][j] = codeword[0] / 2
                    break
            elif k == K-1:
                if codeword[-1] <= _t:
                    target[i][j] = (codeword[-1] + 255) / 2
                    break
            else:
                if codeword[k-1] <= _t < codeword[k]:
                    target[i][j] = (codeword[k-1] + codeword[k]) / 2
                    break
# Out:
# /Users/namuongkang/Library/Python/3.6/lib/python/site-packages/ipykernel_launcher.py:15: RuntimeWarning: overflow encountered in ubyte_scalars
#   from ipykernel import kernelapp as app

# %%
target
# Out:
# array([[110, 110, 110, ...,  31,  31,  31],
#        [110, 110, 110, ...,  31,  31,  31],
#        [110, 110, 110, ...,  31,  31,  31],
#        ...,
#        [110, 110, 110, ...,  56,  56,  56],
#        [110, 110, 110, ...,  56,  56,  56],
#        [110, 110, 110, ...,  56,  56,  56]], dtype=uint8)

# %%
plt.imshow(target, cmap='gray', vmin=0, vmax=255)

# %%
plt.imshow(img, cmap='gray', vmin=0, vmax=255)

# %%
img
# Out:
# array([[121, 120, 121, ..., 168, 168, 168],
#        [122, 120, 119, ..., 170, 169, 169],
#        [122, 120, 119, ..., 171, 170, 170],
#        ...,
#        [114, 116, 109, ..., 191, 190, 190],
#        [112, 110, 107, ..., 192, 191, 191],
#        [112, 110, 107, ..., 192, 191, 191]], dtype=uint8)

# %% [markdown]
# # K means clustering

# %%
import cv2
from sklearn.cluster import KMeans
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt

num_of_clusters = 20

#Read the image
image = cv2.imread('original.jpeg')
plt.imshow(image)
plt.show()

#Dimension of the original image
rows = image.shape[0]
cols = image.shape[1]

#Flatten the image
image = image.reshape(rows*cols, 3)

#Implement k-means clustering to form k clusters
kmeans = KMeans(n_clusters=num_of_clusters)
kmeans.fit(image)

#Replace each pixel value with its nearby centroid
compressed_image = kmeans.cluster_centers_[kmeans.labels_]
compressed_image = np.clip(compressed_image.astype('uint8'), 0, 255)

#Reshape the image to original dimension
compressed_image = compressed_image.reshape(rows, cols, 3)

#Save and display output image
im = Image.fromarray(target)
im.save("compressed_image_{}.png".format(num_of_clusters))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-fa8f2576d439> in <module>
#      21 #Implement k-means clustering to form k clusters
#      22 kmeans = KMeans(n_clusters=num_of_clusters)
# ---> 23 kmeans.fit(image)
#      24
#      25 #Replace each pixel value with its nearby centroid
#
# ~/Library/Python/3.6/lib/python/site-packages/sklearn/cluster/k_means_.py in fit(self, X, y, sample_weight)
#     970                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     971                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 972                 return_n_iter=True)
#     973         return self
#     974
#
# ~/Library/Python/3.6/lib/python/site-packages/sklearn/cluster/k_means_.py in k_means(X, n_clusters, sample_weight, init, precompute_distances, n_init, max_iter, verbose, tol, random_state, copy_x, n_jobs, algorithm, return_n_iter)
#     379                 verbose=verbose, precompute_distances=precompute_distances,
#     380                 tol=tol, x_squared_norms=x_squared_norms,
# --> 381                 random_state=random_state)
#     382             # determine if these results are the best so far
#     383             if best_inertia is None or inertia < best_inertia:
#
# ~/Library/Python/3.6/lib/python/site-packages/sklearn/cluster/k_means_.py in _kmeans_single_elkan(X, sample_weight, n_clusters, max_iter, init, verbose, x_squared_norms, random_state, tol, precompute_distances)
#     443     centers, labels, n_iter = k_means_elkan(X, checked_sample_weight,
#     444                                             n_clusters, centers, tol=tol,
# --> 445                                             max_iter=max_iter, verbose=verbose)
#     446     if sample_weight is None:
#     447         inertia = np.sum((X - centers[labels]) ** 2, dtype=np.float64)
#
# sklearn/cluster/_k_means_elkan.pyx in sklearn.cluster._k_means_elkan.k_means_elkan()
#
# ~/Library/Python/3.6/lib/python/site-packages/sklearn/metrics/pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     163
#     164 # Pairwise distances
# --> 165 def euclidean_distances(X, Y=None, Y_norm_squared=None, squared=False,
#     166                         X_norm_squared=None):
#     167     """
#
# KeyboardInterrupt:
